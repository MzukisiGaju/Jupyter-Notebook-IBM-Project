# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mzukisi**
# I would like to be a Data Scientist, work for a tech company.

# %% [markdown]
# *I am am interested in Data Science because is the most valuable asset in the world surpassing oil. Data Science can help any organization or company to make better decisions.*

# %% [markdown]
# ### Will add two numbers together, to bring total

# %%
5 + 5
# Out:
# 10

# %% [markdown]
# ***
#
#
# * Data Science
# * Data analyst
# * Machine Learning
#
# Numbered list of animals:
# 1. Cat
# 2. Lion
# 3. Elephant
# 4. Rhino
#
# [This is a link to Linkedin](linkedin.com/in/mzukisi-gaju-72026719a/)
#
# ![image of a dog](attachment:ffc9e07b-f797-4ac2-8938-3acf9b9de2db.jpg)
#
# <code> Python
#     mylist = ['DataBoy', 7, True] <code>
# """ Python
#     mylist = ['DataBoy', 7, True]"""
#
# > Believe you can and you're halfway there. **Theodore Roosevelt**
#
# Python is an object oriented programming langauge. ~~Remove this part as it is a draft~~
